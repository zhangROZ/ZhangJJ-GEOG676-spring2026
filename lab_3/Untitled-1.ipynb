# %%
import arcpy

# %%
print(arcpy.ListEnvironments())
# Out:
# ['autoCommit', 'XYResolution', 'processingServerUser', 'gpuId', 'XYDomain', 'processingServerPassword', 'scratchWorkspace', 'recycleProcessingWorkers', 'cartographicPartitions', 'terrainMemoryUsage', 'MTolerance', 'compression', 'coincidentPoints', 'baUseDetailedAggregation', 'timeZone', 'curveProcessingMethod', 'randomGenerator', 'outputCoordinateSystem', 'rasterStatistics', 'transferGDBAttributeProperties', 'ZDomain', 'cellSizeProjectionMethod', 'maintainCurveSegments', 'transferDomains', 'S100FeatureCatalogueFile', 'maintainAttachments', 'resamplingMethod', 'snapRaster', 'cartographicCoordinateSystem', 'baNetworkSource', 'configKeyword', 'matchMultidimensionalVariable', 'outputZFlag', 'qualifiedFieldNames', 'baUseSegmentNames', 'tileSize', 'annotationTextStringFieldLength', 'parallelProcessingFactor', 'pyramid', 'referenceScale', 'processingServer', 'extent', 'unionDimension', 'XYTolerance', 'daylightSaving', 'tinSaveVersion', 'nodata', 'MDomain', 'cellSize', 'outputZValue', 'outp
# ...

# %%
arcpy.env.workspace = r'D:\Spring2026_Courses\GEOG676'
arcpy.env.scratchWorkspace = r'D:\Spring2026_Courses\GEOG676'

# %%
folder_path = r'D:\Spring2026_Courses\GEOG676'
arcpy.CreateFileGDB_management(folder_path, 'Test.gdb')
# Out:
# <Result 'D:\\Spring2026_Courses\\GEOG676\\Test.gdb'>
