# %%
file = open(r"D:\WRF_CHEM\run.txt",'r')

# %%
nfl_teams = file.readlines()
for line in nfl_teams:
    print(line)
file.close()

# %%
try:
    file = open(r"D:\WRF_CHEM\run.txt",'r')
    data = file.read()
    file.close()
except IOError:
    print('An error')

# %%
rawString = r"This\nwill\nnot\nbe\non\nmultiple\nlines"
rawString1 = "This\nwill\nnot\nbe\non\nmultiple\nlines"

print(rawString)
print(rawString1)
# Out:
# This\nwill\nnot\nbe\non\nmultiple\nlines
# This
# will
# not
# be
# on
# multiple
# lines

# %%
import re
result = re.match('c','cat')
print(result)
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
result = re.match('a','cat')
print(result)
# Out:
# None

# %%
result = re.search("i", "abcdefghijklmnopqrstuvwxyz")
print(result)
# Out:
# <re.Match object; span=(8, 9), match='i'>

# %%
s = '100 NORTH BROAD ROAD'
result = re.sub('ROAD$', 'RD.', s)

result = re.sub('ROAD', 'RD.', s)
print(result)
# Out:
# 100 NORTH BRD. RD.

# %%
x = "6 geese a-layin' 51 golden rings 4 calling birds 33 French hens 2 turtle doves 91 partridge in a pear tree"
result = re.findall(r"\d+", x)
print(result)
# Out:
# ['6', '51', '4', '33', '2', '91']

# %%
class Car:
    def __init__(self) -> None:
        pass
    def setColor(self,newColor):
        self.color=newColor
    def honkHorn(self):
        print('Beep beep')
class Truck:
    def __init__(self,value):
        self.mpg = value
x=Truck(17)

# %%
x.mpg
# Out:
# 17

# %%
chevy=Car()
chevy.setColor('red')
chevy.honkHorn()
# Out:
# Beep beep

# %%
chevy.color
# Out:
# 'red'

# %%
class Truck:
    numOfWheels = 4 
    def __init__(self, color):
        self.color = color 
aaa=Truck()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       3     def __init__(self, color):
#       4         self.color = color
# ----> 5 aaa=Truck()
#
# TypeError: Truck.__init__() missing 1 required positional argument: 'color'

# %%
aaa=Truck('red')

# %%
aaa.color
# Out:
# 'red'

# %%
aaa.tinted = True

# %%
aaa.tinted
# Out:
# True

# %%
aaa.numOfWheels
# Out:
# 4

# %%
class Atom:
    def __init__(self, atno, x, y, z):
        self.atno = atno
        self.__position = (x, y, z) #__position is private
    def getPosition(self):
        return self.__position
    def setPosition(self, x, y, z):
        self.__position = (x, y, z)
    def translate(self, x, y, z):
        x0, y0, z0 = self.__position
        self.__position = (x0 + x, y0 + y, z0 + z)

atom = Atom(14, 1, 1, 2)

# %%
atom.atno
# Out:
# 14

# %%
atom.__position
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 atom.__position
#
# AttributeError: 'Atom' object has no attribute '__position'

# %%
atom.getPosition()
# Out:
# (1, 1, 2)

# %%
atom._Atom__position
# Out:
# (13, 19, 50)

# %%
atom.translate(2, 3, 8)

atom.getPosition()
# Out:
# (13, 19, 50)

# %%
value = -8271.18
absolute_value = abs(value)
print(absolute_value)
# Out:
# 8271.18
